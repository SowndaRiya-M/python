# %%
#how to create a series with list
import numpy as np
import pandas as pd
a=pd.Series(list(('riya','ram','ragu')))
print(a)
# Out:
# 0    riya
# 1     ram
# 2    ragu
# dtype: object

# %%
https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars2.csv

# %%
import numpy as np
#dot product
a =[1,2,3]
b=[1,2,3]
print(np.dot(a,b))
# Out:
# 14

# %% [markdown]
# numpy.dot(a, b, out=None)
# Dot product of two arrays. Specifically,
#
# If both a and b are 1-D arrays, it is inner product of vectors (without complex conjugation).
#
# If both a and b are 2-D arrays, it is matrix multiplication, but using matmul or a @ b is preferred.
#
# If either a or b is 0-D (scalar), it is equivalent to multiply and using numpy.multiply(a, b) or a * b is preferred.
#
# If a is an N-D array and b is a 1-D array, it is a sum product over the last axis of a and b.
#
# If a is an N-D array and b is an M-D array (where M>=2), it is a sum product over the last axis of a and the second-to-last axis of b:

# %%
# !pip install plotly
# !pip install cufflinks
# !pip install foliu
# Out:
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11435 sha256=4cc8c06f22eac2d42b2d602dfae4dde9c2aa34d0c5d90b0f642ffa89214b6c7d
#   Stored in directory: c:\users\sowndariya\appdata\local\pip\cache\wheels\f9\8d\8d\f6af3f7f9eea3553bc2fe6d53e4b287dad18b06a861ac56ddf
# Successfully built retrying
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68729 sha256=95e679deaad15725455d1d7b211d06de5285f7e8def9744787c12ced8f6ced2c
#   Stored in directory: c:\users\sowndariya\appdata\local\pip\cache\wheels\e1\27\13\3fe67fa7ea7be444b831d117220b3b586b872c9acd4df480d0
# Successfully built cufflinks
# ...
# ERROR: Could not find a version that satisfies the requirement foliu (from versions: none)
# ERROR: No matching distribution found for foliu

# %%
#how to create a series with array
arr=np.array(['riya','ram','raj'])
series=pd.Series(arr)
series
# Out:
# 0    riya
# 1     ram
# 2     raj
# dtype: object

# %%
import pandas as pd
import numpy as np
dictt=pd.Series([1,2,3,4,5,6],index=['apple','orange','kiwi','grapes','musambi',np.NaN])
a=dictt.loc[['apple','orange','grapes']]
print(a)
b=dictt.iloc[2]
print(b)
# Out:
# apple     1
# orange    2
# grapes    4
# dtype: int64
# 3

# %%
#with scalar
scal=pd.Series(7,index=['ria','asha','arav'])
scal
# Out:
# ria     7
# asha    7
# arav    7
# dtype: int64

# %%
import pandas as pd
dictt=pd.Series([1,2,3,4,5],index=['apple','orange','kiwi','grapes','musambi'])
dictt1=pd.Series([11,22,33,1,2,8,10],index=['apple','orange','kiwi','grapes','div','avacoda','mango'])
dicc=dictt1+dictt
aa=dicc.fillna(0)
aa.astype(int)
bb=dictt.add(dictt1,fill_value=0)
bb
# Out:
# apple      12.0
# avacoda     8.0
# div         2.0
# grapes      5.0
# kiwi       36.0
# mango      10.0
# musambi     5.0
# orange     24.0
# dtype: float64

# %%
dfmovie=pd.DataFrame({'movie1':[1,2,3,4,5],'movie2':[6,7,8,9,10]},index=['tom','jerry','igloo','iceage','premam'])
dfmovie
# Out:
#         movie1  movie2
# tom          1       6
# jerry        2       7
# igloo        3       8
# iceage       4       9
# premam       5      10

# %%
df_movie_rating = pd.DataFrame({'movie 1':[5,4,3,3,2,1], 'movie 2': [4,5,2,3,4,2]},
                              index = ['Tom', 'Jeff', 'Peter', 'Ram', 'Ted', 'Paul'])

#df_movie_rating = pd.DataFrame({'movie 1':[5,4,3,3,2,1], 'movie 2': [4,5,2,3,4,2]},
                              #index = ['Tom', 'Jeff', 'Peter', 'Ram', 'Ted', 'Paul'])
def movie_rating(num):
    if num==5:
        return 'A'
    elif num==4:
        return 'B'
    elif num==3:
        return 'C'
    elif num==2:
        return 'A'
    else:
        return 'E'
df_movie_rating.applymap(movie_rating)
aaaa=df_movie_rating['movie 2'].apply(movie_rating)
aaaa
# Out:
# Tom      B
# Jeff     A
# Peter    A
# Ram      C
# Ted      B
# Paul     A
# Name: movie 2, dtype: object

# %%
df_test=pd.DataFrame({'Test1':[99,98,97,96,95,100],'Test2':[89,90,65,78,100,100]},index=['vikki','riya','soundar','ram','raja','akalya'])
print(df_test.max())
print(df_test.min())
print(df_test.mean())
# Out:
# Test1    100
# Test2    100
# dtype: int64
# Test1    95
# Test2    65
# dtype: int64
# Test1    97.5
# Test2    87.0
# dtype: float64

# %%
import pandas as pd
df_president_name = pd.DataFrame({'first':['George','Bill','Ronald','Jimmy', 'George'],
                                 'last':['Bush', 'Clinton','Regan','Carter','Washington']})
aa=df_president_name.groupby('first').get_group('Ronald')
print(aa)
bb=df_president_name.sort_values(['first','last'],ascending=False)
bb
# Out:
#     first   last
# 2  Ronald  Regan
#     first        last
# 2  Ronald       Regan
# 3   Jimmy      Carter
# 4  George  Washington
# 0  George        Bush
# 1    Bill     Clinton

# %%
#create dataframe
import pandas as pd
data={'name':['ram','riya','raj'],'rank':[1,2,3],'year':['1st','2nd','3rd']}
frame=pd.DataFrame(data)
print(frame)
frame.loc[[0,1]]
frame.iloc[0:3]
# Out:
#    name  rank year
# 0   ram     1  1st
# 1  riya     2  2nd
# 2   raj     3  3rd
#    name  rank year
# 0   ram     1  1st
# 1  riya     2  2nd
# 2   raj     3  3rd

# %%
import pandas as pd
datas={'S.NO':[1,2,3],'name':['ram','riya','raj'],'year':['1st','2nd','3rd'],'marks':[100,99,98]}
frame=pd.DataFrame(datas)
print(frame)
a=frame.loc[0]
print(a)
# Out:
#    S.NO  name year  marks
# 0     1   ram  1st    100
# 1     2  riya  2nd     99
# 2     3   raj  3rd     98
# S.NO       1
# name     ram
# year     1st
# marks    100
# Name: 0, dtype: object

# %%
dictt=pd.Series([1,2,3,4,5],index=['apple','orange','kiwi','grapes','musambi'])
dictt1=pd.Series([11,21,13,14,51],index=['apple','orange','kiwi','grapes','musambi'])
df=pd.DataFrame({'I':dictt,'II':dictt1})
df
# Out:
#          I  II
# apple    1  11
# orange   2  21
# kiwi     3  13
# grapes   4  14
# musambi  5  51

# %%
#from dictionary df created
arrr=np.array([100,101,102,103])
dicttt={'marks':arrr}
dff=pd.DataFrame(dicttt)
dff
# Out:
#    marks
# 0    100
# 1    101
# 2    102
# 3    103

# %%
new_df=pd.DataFrame(dff)
new_df
# Out:
#    marks
# 0    100
# 1    101
# 2    102
# 3    103

# %%
import pandas as pd
import csv
df = pd.read_csv('C:/Users/sowndariya/Desktop/xxx.csv')
df.head()
type(df)
print(df.shape)
print(df.columns)
print(df.dtypes)
print(df.info())
#df_country=df['country']
df_country=df.country
df_country.head()
df_country.tail()
subset=df[['country','year','continent']]
print(subset.head())
print(subset.tail())
df.tail()
# Out:
# (1704, 6)
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB
# None
#        country  year continent
# 0  Afghanistan  1952      Asia
# 1  Afghanistan  1957      Asia
# 2  Afghanistan  1962      Asia
# 3  Afghanistan  1967      Asia
# 4  Afghanistan  1972      Asia
#        country  year continent
# ...

# %%
df.tail(2)
df.iloc[3:4]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 3  Afghanistan      Asia  1967    34.02  11537966  836.197138

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('C:/Users/sowndariya/Desktop/xxx.csv')
no_of_rows=df.shape[0]-2#to get the last row
df.loc[no_of_rows]
print(df.tail())
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
print(df.groupby(['country'])[['lifeExp','gdpPercap']].mean())
global_yearly_life_expectancy = df.groupby('year')['lifeExp'].mean()
global_yearly_life_expectancy.plot()
# Out:
#                       lifeExp    gdpPercap
# country
# Afghanistan         37.478833   802.674598
# Albania             68.432917  3255.366633
# Algeria             59.030167  4426.025973
# Angola              37.883500  3607.100529
# Argentina           69.060417  8955.553783
# ...                       ...          ...
# Vietnam             57.479500  1017.712615
# West Bank and Gaza  60.328667  3759.996781
# Yemen, Rep.         46.780417  1569.274672
# Zambia              45.996333  1358.199409
# Zimbabwe            52.663167   635.858042
#
# [142 rows x 2 columns]

# %%
import pandas as pd
s=pd.Series([1,2,3,4],index=['sowndariya','ram','soundar','raj'])
s
# Out:
# sowndariya    1
# ram           2
# soundar       3
# raj           4
# dtype: int64

# %%
scientist=pd.DataFrame({'Designation':['statistician','chemist'],
                        'salary':['100000','5687879']}
                       ,index=['Einstein','Newton'],columns=['Designation','salary'])

scientist
# Out:
#            Designation   salary
# Einstein  statistician   100000
# Newton         chemist  5687879

# %%
import numpy as np
p=scientist.loc['Einstein']#index value
print(p.index)
print(p.values)
print(p.keys()[1])
print(p.index[0])
salary=(scientist['salary'])
print(salary.mean())
print(salary.min())
print(salary.max())
# Out:
# Index(['Designation', 'salary'], dtype='object')
# ['statistician' '100000']
# salary
# Designation
# 500002843939.5
# 100000
# 5687879

# %% [markdown]
# The monthly phone bills in a city are normally distributed with a mean of 30$ and a standard deviation of 12$. Find the x-value that correspond to z-scores of 3.17

# %%
#μ = 70 , σ = 8 , X = 50
x=50
u=70
s=8
z=(x-u)/s
print(z)
# Out:
# -2.5

# %%
import pandas as pd
c=['sl','sw','pl','pw','Species']
dff=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",names=c)
df=dff.copy()
df.head()
df.shape
df.head(10)
print(df.dtypes)
df.columns
df.describe()
df.sl
df['sl']
print(df.isnull().sum())
print(df.iloc[1:4,3:4])
df.drop(df.index[1],inplace=True)
df.head()
df[df.pw<=0.5]
print(df[df.Species=='Iris-setosa'].describe())
(df.iloc[1:9,3:4])
df.head(9)
df.pl.value_counts()
df=df.loc[(df.Species=="Iris-setosa")&(df.pl>1.5)&(df.sl>1.5)]
df.sort_values('pl',ascending=True)
df.sort_index()
# Out:
# sl         float64
# sw         float64
# pl         float64
# pw         float64
# Species     object
# dtype: object
# sl         0
# sw         0
# pl         0
# pw         0
# Species    0
# dtype: int64
#     pw
# 1  0.2
# 2  0.2
# 3  0.2
#               sl         sw         pl         pw
# count  49.000000  49.000000  49.000000  49.000000
# mean    5.008163   3.426531   1.465306   0.244898
# std     0.355807   0.380118   0.175061   0.108130
# min     4.300000   2.300000   1.000000   0.100000
# 25%     4.800000   3.200000   1.400000   0.200000
# 50%     5.000000   3.400000   1.500000   0.200000
# 75%     5.200000   3.700000   1.600000   0.300000
# max     5.800000   4.400000   1.900000   0.600000
#      sl   sw   pl   pw      Species
# 5   5.4  3.9  1.7  0.4  Iris-setosa
# 11  4.8  3.4  1.6  0.2  Iris-setosa
# 18  5.7  3.8  1.7  0.3  Iris-setosa
# 20  5.4  3.4  1.7  0.2  Iris-setosa
# 23  5.1  3.3  1.7  0.5  Iris-setosa
# 24  4.8  3.4  1.9  0.2  Iris-setosa
# ...

# %%
mean=df[df.Species=='Iris-setosa']
mean.pl.mean()
yr=len(set(df.sl))
print(yr)
df
# Out:
#      sl   sw   pl   pw      Species
# 5   5.4  3.9  1.7  0.4  Iris-setosa
# 11  4.8  3.4  1.6  0.2  Iris-setosa
# 18  5.7  3.8  1.7  0.3  Iris-setosa
# 20  5.4  3.4  1.7  0.2  Iris-setosa
# 23  5.1  3.3  1.7  0.5  Iris-setosa
# 24  4.8  3.4  1.9  0.2  Iris-setosa
# 25  5.0  3.0  1.6  0.2  Iris-setosa
# 26  5.0  3.4  1.6  0.4  Iris-setosa
# 29  4.7  3.2  1.6  0.2  Iris-setosa
# 30  4.8  3.1  1.6  0.2  Iris-setosa
# 43  5.0  3.5  1.6  0.6  Iris-setosa
# 44  5.1  3.8  1.9  0.4  Iris-setosa
# 46  5.1  3.8  1.6  0.2  Iris-setosa

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("http://rcs.bu.edu/examples/python/data_analysis/Salaries.csv")
df[['phd','salary']]
df.info()
df.axes
df.size
df.shape[0]
df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
import statistics
a=df.iloc[1:50]
a.mean()
# Out:
# phd            20.816327
# service        16.959184
# salary     112295.857143
# dtype: float64

# %%
df.salary.describe()
df[['salary']].count()
df[['salary']].mean()
# Out:
# salary    108023.782051
# dtype: float64

# %%
dfrank=df.groupby(['rank'])
dfrank.mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
a=df.groupby('rank').size()
a
# Out:
# rank
# AssocProf    13
# AsstProf     19
# Prof         46
# dtype: int64

# %%
a=df.groupby('rank')[['rank']]
print(a)
a.count()
# Out:
# ...
#            rank
# rank
# AssocProf    13
# AsstProf     19
# Prof         46

# %%
a=df[['phd','salary']].iloc[30:46]
a
# Out:
#     phd  salary
# 30    9  107008
# 31   22  155750
# 32   27  103275
# 33   18  120000
# 34   12  119800
# 35   28  126933
# 36   45  146856
# 37   20  102000
# 38    4   91000
# 39   18  129000
# 40   39  137000
# 41   13   74830
# 42    4   80225
# 43    5   77000
# 44   23  151768
# 45   25  140096

# %%
df_sub=df[df['salary']>120000]
df_sub.index[10:15]
df.loc[[10,14],['phd','sex']]
# Out:
#     phd   sex
# 10   39  Male
# 14   25  Male

# %%
dff=df.sort_values(by=['salary','sex'],ascending=[True,False])
dff.head()
# Out:
#          rank discipline  phd  service     sex  salary
# 9        Prof          A   51       51    Male   57800
# 54  AssocProf          A   25       22  Female   62884
# 66   AsstProf          A    7        6  Female   63100
# 71  AssocProf          B   12        9  Female   71065
# 55   AsstProf          A    2        0  Female   72500

# %%
q=df['salary'].agg(['min','max','mean'])
q
# Out:
# min      57800.000000
# max     186960.000000
# mean    108023.782051
# Name: salary, dtype: float64

# %%
df[['salary']].agg(['min','max'])
# Out:
#      salary
# min   57800
# max  186960

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
import pandas as pd
import numpy as np
c=['sl','sw','pl','pw','Species']
iris=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data",names=c,header=None)
a=iris.loc[(iris.Species=='Iris-virginica')&(iris.pl>1.5)]
print(a)
npl=np.array(a)

for i in range(0,len(npl)):
    for j in range(0,5):
        print(npl[i,j],end=' ')
    print()
# Out:
#       sl   sw   pl   pw         Species
# 100  6.3  3.3  6.0  2.5  Iris-virginica
# 101  5.8  2.7  5.1  1.9  Iris-virginica
# 102  7.1  3.0  5.9  2.1  Iris-virginica
# 103  6.3  2.9  5.6  1.8  Iris-virginica
# 104  6.5  3.0  5.8  2.2  Iris-virginica
# 105  7.6  3.0  6.6  2.1  Iris-virginica
# 106  4.9  2.5  4.5  1.7  Iris-virginica
# 107  7.3  2.9  6.3  1.8  Iris-virginica
# 108  6.7  2.5  5.8  1.8  Iris-virginica
# 109  7.2  3.6  6.1  2.5  Iris-virginica
# 110  6.5  3.2  5.1  2.0  Iris-virginica
# 111  6.4  2.7  5.3  1.9  Iris-virginica
# 112  6.8  3.0  5.5  2.1  Iris-virginica
# 113  5.7  2.5  5.0  2.0  Iris-virginica
# 114  5.8  2.8  5.1  2.4  Iris-virginica
# 115  6.4  3.2  5.3  2.3  Iris-virginica
# 116  6.5  3.0  5.5  1.8  Iris-virginica
# 117  7.7  3.8  6.7  2.2  Iris-virginica
# 118  7.7  2.6  6.9  2.3  Iris-virginica
# 119  6.0  2.2  5.0  1.5  Iris-virginica
# 120  6.9  3.2  5.7  2.3  Iris-virginica
# 121  5.6  2.8  4.9  2.0  Iris-virginica
# ...

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("http://rcs.bu.edu/examples/python/data_analysis/Salaries.csv")
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
import os
import numpy as np
import pandas as pd
df=pd.read_csv("Indian_cities.csv")
print(df.shape)
df.describe()
df.dtypes
# Out:
# (493, 22)
# name_of_city                       object
# state_code                          int64
# state_name                         object
# dist_code                           int64
# population_total                    int64
# population_male                     int64
# population_female                   int64
# 0-6_population_total                int64
# 0-6_population_male                 int64
# 0-6_population_female               int64
# literates_total                     int64
# literates_male                      int64
# literates_female                    int64
# sex_ratio                           int64
# child_sex_ratio                     int64
# effective_literacy_rate_total     float64
# effective_literacy_rate_male      float64
# effective_literacy_rate_female    float64
# location                           object
# total_graduates                     int64
# male_graduates                      int64
# female_graduates                    int64
# dtype: object

# %%
df = pd.read_csv(r'C:\Users\sowndariya\Desktop\CNN\terrorismData.csv')
df=df[df['State']=='Jammu and Kashmir']
x = df.City.value_counts()
city = x.index[0]
value = x.values[0]
df=df[df['Group']!='Unknown']
df=df[df['City']==city]
y = df.Group.value_counts()
name = y.index[0]
print(city,value,name)
# Out:
# Srinagar 657 Muslim Separatists

# %%
os.chdir('C:/Users/sowndariya/Desktop/CNN')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sowndariya\\Desktop\\CNN'

# %%
import os
import numpy as np
import pandas as pd
df=pd.read_csv("Indian_cities.csv")
a=df['sex_ratio'].value_counts()
ind=a.index[0]
aa=df[df['name_of_city']==ind]
aa
# Out:
# Empty DataFrame
# Columns: [name_of_city, state_code, state_name, dist_code, population_total, population_male, population_female, 0-6_population_total, 0-6_population_male, 0-6_population_female, literates_total, literates_male, literates_female, sex_ratio, child_sex_ratio, effective_literacy_rate_total, effective_literacy_rate_male, effective_literacy_rate_female, location, total_graduates, male_graduates, female_graduates]
# Index: []
#
# [0 rows x 22 columns]

# %%
import os
import numpy as np
import pandas as pd
df=pd.read_csv("Indian_cities.csv")
df[df.sex_ratio==df.sex_ratio.max()]
print(df[df.sex_ratio==df.sex_ratio.min()])
a=df.sort_values('sex_ratio',ascending=False)
a.head(5)
# Out:
#    name_of_city  state_code   state_name  dist_code  population_total  \
# 89    Bhiwandi           27  MAHARASHTRA         21            711329
#
#     population_male  population_female  0-6_population_total  \
# 89           418478             292851                 88613
#
#     0-6_population_male  0-6_population_female  ...  literates_female  \
# 89                45820                  42793  ...            192816
#
#     sex_ratio  child_sex_ratio  effective_literacy_rate_total  \
# 89        700              934                          81.53
#
#     effective_literacy_rate_male  effective_literacy_rate_female  \
# 89                          84.5                           77.11
#
#                  location  total_graduates male_graduates  female_graduates
# 89  19.2812547,73.0482912            24688          14404             10284
#
# [1 rows x 22 columns]
#             name_of_city  state_code state_name  dist_code  population_total  \
# ...

# %%
a=df.sort_values('sex_ratio')
a.head(1)
# Out:
#    name_of_city  state_code   state_name  dist_code  population_total  \
# 89    Bhiwandi           27  MAHARASHTRA         21            711329
#
#     population_male  population_female  0-6_population_total  \
# 89           418478             292851                 88613
#
#     0-6_population_male  0-6_population_female  ...  literates_female  \
# 89                45820                  42793  ...            192816
#
#     sex_ratio  child_sex_ratio  effective_literacy_rate_total  \
# 89        700              934                          81.53
#
#     effective_literacy_rate_male  effective_literacy_rate_female  \
# 89                          84.5                           77.11
#
#                  location  total_graduates male_graduates  female_graduates
# 89  19.2812547,73.0482912            24688          14404             10284
#
# [1 rows x 22 columns]

# %%
sex=df.groupby('state_name')['population_female']
sex
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-dea9b5ac14ab> in <module>
# ----> 1 sex=df.groupby('state_name')['population_female']
#       2 sex
#
# D:\Programdata\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     237         else:
#     238             if key not in self.obj:
# --> 239                 raise KeyError(f"Column not found: {key}")
#     240             return self._gotitem(key, ndim=1)
#     241
#
# KeyError: 'Column not found: population_female'

# %%
df=df.sort_values('sex_ratio',ascending=True)
a=df.groupby('state_name')[['sex_ratio']]
a.mean()
# Out:
#                              sex_ratio
# state_name
# ANDAMAN & NICOBAR ISLANDS   889.000000
# ANDHRA PRADESH              999.404762
# ASSAM                       950.750000
# BIHAR                       887.884615
# CHANDIGARH                  829.000000
# CHHATTISGARH                950.222222
# GUJARAT                     913.172414
# HARYANA                     875.800000
# HIMACHAL PRADESH            818.000000
# JAMMU & KASHMIR             907.666667
# JHARKHAND                   903.000000
# KARNATAKA                   987.115385
# KERALA                     1066.714286
# MADHYA PRADESH              914.812500
# MAHARASHTRA                 920.511628
# MANIPUR                    1055.000000
# MEGHALAYA                  1042.000000
# MIZORAM                    1029.000000
# NAGALAND                    904.000000
# NCT OF DELHI                861.533333
# ORISSA                      930.300000
# PUDUCHERRY                 1035.000000
# PUNJAB                      887.062500
# ...

# %%
a=df.groupby('state_name')[['sex_ratio']]
a.mean().sort_values("sex_ratio").head()
# Out:
#                    sex_ratio
# state_name
# HIMACHAL PRADESH  818.000000
# CHANDIGARH        829.000000
# NCT OF DELHI      861.533333
# HARYANA           875.800000
# PUNJAB            887.062500

# %%
d=df.sort_values('sex_ratio',ascending=True)
d.head(5)
# Out:
#          state_name  sex_ratio
# 89      MAHARASHTRA        700
# 142    NCT OF DELHI        719
# 88        RAJASTHAN        755
# 449         GUJARAT        758
# 374  MADHYA PRADESH        787

# %%
array_length = int(input('Enter the length of list : '))
array_element = []
array_diff = []

for i in range(array_length):
    array_element.append(int(input('Value : ')))
print(array_element)

for j, value_1 in enumerate(array_element):
    for k, value_2 in enumerate(array_element):
        if value_1==value_2 and j!=k:
            temp = abs(j-k)
            array_diff.append(temp)
print(array_diff)        
print(max(array_diff))
# Out:
# Enter the length of list : 5
# Value : 0
# Value : 1
# Value : 2
# Value : 3
# Value : 4
# [0, 1, 2, 3, 4]
# []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-98b9a43cfd99> in <module>
#      13             array_diff.append(temp)
#      14 print(array_diff)
# ---> 15 print(max(array_diff))
#
# ValueError: max() arg is an empty sequence

# %%
import numpy as np
import pandas as pd
data=pd.read_csv("Indian_cities.csv")
data.columns
# Out:
# Index(['name_of_city', 'state_code', 'state_name', 'dist_code',
#        'population_total', 'population_male', 'population_female',
#        '0-6_population_total', '0-6_population_male', '0-6_population_female',
#        'literates_total', 'literates_male', 'literates_female', 'sex_ratio',
#        'child_sex_ratio', 'effective_literacy_rate_total',
#        'effective_literacy_rate_male', 'effective_literacy_rate_female',
#        'location', 'total_graduates', 'male_graduates', 'female_graduates'],
#       dtype='object')

# %%
### City with lowest Sex-Ratio 
lowest=data.sort_values('sex_ratio',ascending=True)
lowest.head(1)
# Out:
#    name_of_city  state_code   state_name  dist_code  population_total  \
# 89    Bhiwandi           27  MAHARASHTRA         21            711329
#
#     population_male  population_female  0-6_population_total  \
# 89           418478             292851                 88613
#
#     0-6_population_male  0-6_population_female  ...  literates_female  \
# 89                45820                  42793  ...            192816
#
#     sex_ratio  child_sex_ratio  effective_literacy_rate_total  \
# 89        700              934                          81.53
#
#     effective_literacy_rate_male  effective_literacy_rate_female  \
# 89                          84.5                           77.11
#
#                  location  total_graduates male_graduates  female_graduates
# 89  19.2812547,73.0482912            24688          14404             10284
#
# [1 rows x 22 columns]

# %%
### City with highest Sex-Ratio 
highest=data.sort_values('sex_ratio',ascending=False)
highest.head(1)
# Out:
#     name_of_city  state_code state_name  dist_code  population_total  \
# 278   Kozhikode           32     KERALA          4            432097
#
#      population_male  population_female  0-6_population_total  \
# 278           206494             225603                 41574
#
#      0-6_population_male  0-6_population_female  ...  literates_female  \
# 278                21208                  20366  ...            196582
#
#      sex_ratio  child_sex_ratio  effective_literacy_rate_total  \
# 278       1093              960                           96.8
#
#      effective_literacy_rate_male  effective_literacy_rate_female  \
# 278                         97.93                           95.78
#
#                 location  total_graduates male_graduates  female_graduates
# 278  11.2587531,75.78041            61225          27701             33524
#
# [1 rows x 22 columns]

# %%
### Mean of Sex- Ratio grouped by States and sorted by sex ratio in ascending order.
mean=data.groupby('state_name')[['sex_ratio']]
mean.mean().sort_values("sex_ratio",ascending=True).head()
# Out:
#                    sex_ratio
# state_name
# HIMACHAL PRADESH  818.000000
# CHANDIGARH        829.000000
# NCT OF DELHI      861.533333
# HARYANA           875.800000
# PUNJAB            887.062500

# %%
### Shows top 5 states having lowest sex-ratio. It should sorted by state name.
low=data.groupby('state_name')[['sex_ratio']]
a=low.mean().sort_values(by=['sex_ratio'],ascending=True).head()
a.sort_values('state_name')
# Out:
#                    sex_ratio
# state_name
# CHANDIGARH        829.000000
# HARYANA           875.800000
# HIMACHAL PRADESH  818.000000
# NCT OF DELHI      861.533333
# PUNJAB            887.062500

# %%
#5 Cities, which have lowest sex- ratio and making a dataframe out of it.
dff=data[['name_of_city','sex_ratio']]
new_df=pd.DataFrame(dff.sort_values('sex_ratio').head())
new_df
# Out:
#           name_of_city  sex_ratio
# 89           Bhiwandi         700
# 142  Delhi Cantonment         719
# 88            Bhiwadi         755
# 449             Surat         758
# 374         Pithampur         787

# %%
### 5 Cities, which have highest sex- ratio and making a dataframe out of it.
dff=data[['name_of_city','sex_ratio']].sort_values('sex_ratio',ascending=False).head()
dff
# Out:
#             name_of_city  sex_ratio
# 278           Kozhikode        1093
# 275              Kollam        1077
# 14            Alappuzha        1076
# 461            Thrissur        1076
# 459  Thiruvananthapuram        1064

# %%
### 5 Cities, which have lowest sex- ratio and making a dataframe out of it.
dff=data[['name_of_city','sex_ratio']]
dff.sort_values('sex_ratio',ascending=True).head()
# Out:
#           name_of_city  sex_ratio
# 89           Bhiwandi         700
# 142  Delhi Cantonment         719
# 88            Bhiwadi         755
# 449             Surat         758
# 374         Pithampur         787

# %%
### Concatenated top 5 and bottom 5 cities on the basis of Sex - Ratio
dff=data[['name_of_city','sex_ratio']]
top=dff.sort_values('sex_ratio',ascending=False).head()
bottom=dff.sort_values('sex_ratio',ascending=True).head()
pd.concat([top,bottom])
# Out:
#             name_of_city  sex_ratio
# 278           Kozhikode        1093
# 275              Kollam        1077
# 14            Alappuzha        1076
# 461            Thrissur        1076
# 459  Thiruvananthapuram        1064
# 89             Bhiwandi         700
# 142    Delhi Cantonment         719
# 88              Bhiwadi         755
# 449               Surat         758
# 374           Pithampur         787

# %%
### Best 5 cities with highest number of female graduates 0-6_population_female
import numpy as np
import pandas as pd
data.sort_values('literates_female',ascending=False)[['name_of_city']].head()
# Out:
#            name_of_city
# 185     Greater Mumbai
# 141              Delhi
# 72            Bengaluru
# 184  Greater Hyderabad
# 7            Ahmadabad

# %%
### Aggregated Sum of population for all the states
total_pop=data[['state_name','population_total']].groupby('state_name').agg('sum')
total_pop
# Out:
#                            population_total
# state_name
# ANDAMAN & NICOBAR ISLANDS            100608
# ANDHRA PRADESH                     18171615
# ASSAM                               1391154
# BIHAR                               6714516
# CHANDIGARH                           960787
# CHHATTISGARH                        3137918
# GUJARAT                            17835049
# HARYANA                             5952223
# HIMACHAL PRADESH                     169758
# JAMMU & KASHMIR                     1804987
# JHARKHAND                           4278259
# KARNATAKA                          15799896
# KERALA                              2755973
# MADHYA PRADESH                     11023091
# MAHARASHTRA                        37722136
# MANIPUR                              264986
# MEGHALAYA                            143007
# MIZORAM                              291822
# NAGALAND                             123777
# NCT OF DELHI                       13481997
# ...

# %%
data.groupby('state_name').population_total.sum()
# Out:
# state_name
# ANDAMAN & NICOBAR ISLANDS      100608
# ANDHRA PRADESH               18171615
# ASSAM                         1391154
# BIHAR                         6714516
# CHANDIGARH                     960787
# CHHATTISGARH                  3137918
# GUJARAT                      17835049
# HARYANA                       5952223
# HIMACHAL PRADESH               169758
# JAMMU & KASHMIR               1804987
# JHARKHAND                     4278259
# KARNATAKA                    15799896
# KERALA                        2755973
# MADHYA PRADESH               11023091
# MAHARASHTRA                  37722136
# MANIPUR                        264986
# MEGHALAYA                      143007
# MIZORAM                        291822
# NAGALAND                       123777
# NCT OF DELHI                 13481997
# ORISSA                        3003234
# PUDUCHERRY                     541801
# PUNJAB                        5821876
# RAJASTHAN                    10443016
# ...

# %%
###  Created a dataframe for only 2 states..Bihar and Kerala...
states2=data.loc[(data.state_name=='BIHAR')|(data.state_name=='KERALA')]
states2
# Out:
#             name_of_city  state_code state_name  dist_code  population_total  \
# 14            Alappuzha           32     KERALA         11            174164
# 31                Arrah           10      BIHAR         29            261099
# 34           Aurangabad           10      BIHAR         33            101520
# 39               Bagaha           10      BIHAR          1            113012
# 69            Begusarai           10      BIHAR         20            251136
# 73              Bettiah           10      BIHAR          1            132896
# 78            Bhagalpur           10      BIHAR         22            398138
# 98          Biharsharif           10      BIHAR         27            296889
# 111               Buxar           10      BIHAR         30            102591
# 117              Chapra           10      BIHAR         17            201597
# 134           Darbhanga           10      BIHAR         13            294116
# ...

# %%
# Histogram plot of Sex Ratio.
plt.hist(data['sex_ratio'],edgecolor='black',bins=20)
plt.show()

# %%
### Histogram plot of Child Sex Ratio.

plt.hist(data['child_sex_ratio'],edgecolor='black',bins=10)
plt.show()

# %%
### Scatterplot between total graduates and female graduates 'total_graduates', 'male_graduates', 'female_graduates'
plt.scatter(data['total_graduates'],data['female_graduates'],s=100,c='b')
plt.show()

# %%
### Distribution of Child sex ratio
import matplotlib.pyplot as plt
plt.hist(data['child_sex_ratio'],edgecolor='violet')
plt.show()

# %%
### Distribution of the data of total effective literacy rate is normal.

plt.hist(data['effective_literacy_rate_total'],bins=20,edgecolor='black')
plt.show()

# %%
### Create 2 new columns - longitude and latitude from a location variable
def lat(locc):
    a=locc.split(',')[1]
    return a
data['latitude']=data['location'].apply(lat)
def long(locc1):
    b=locc1.split(',')[0]
    return b
data['longitude']=data['location'].apply(long)
data.sample(n=1)
data.sample(frac=0.5)
# Out:
#     name_of_city  state_code      state_name  dist_code  population_total  \
# 328      Nadiad           24         GUJARAT         16            218150
# 322     Murwara           23  MADHYA PRADESH         33            221875
# 81      Bharuch           24         GUJARAT         21            168729
# 403        Rewa           23  MADHYA PRADESH         13            235422
# 273    Kolhapur           27     MAHARASHTRA         34            549283
# ..           ...         ...             ...        ...               ...
# 229  Jalpaiguri           19     WEST BENGAL          2            107351
# 163    Faizabad            9   UTTAR PRADESH         46            167544
# 409    Rudrapur            5     UTTARAKHAND         12            140884
# 349     Neyveli           33      TAMIL NADU         16            105687
# 106      Budaun            9   UTTAR PRADESH         18            159221
#
#      population_male  population_female  0-6_population_total  \
# ...

# %%
data1=data.copy()
def func(num):
    return num.split(',')[0] 
def func1(num):
    return num.split(',')[1] 
    
data1['long']=data1['location'].apply(func)
data1['lat']=data1['location'].apply(func1)
data1
# Out:
#       name_of_city  state_code      state_name  dist_code  population_total  \
# 0          Abohar            3          PUNJAB          9            145238
# 1        Achalpur           27     MAHARASHTRA          7            112293
# 2        Adilabad           28  ANDHRA PRADESH          1            117388
# 3       Adityapur           20       JHARKHAND         24            173988
# 4           Adoni           28  ANDHRA PRADESH         21            166537
# ..             ...         ...             ...        ...               ...
# 488  Vizianagaram           28  ANDHRA PRADESH         12            227533
# 489      Warangal           28  ANDHRA PRADESH          9            620116
# 490        Wardha           27     MAHARASHTRA          8            105543
# 491   Yamunanagar            6         HARYANA          3            216628
# 492      Yavatmal           27     MAHARASHTRA         14            116714
#
# ...

# %%
data1[['longitude', 'latitude']] = data1.location.str.split(',',expand=True)
data1
# Out:
#       name_of_city  state_code      state_name  dist_code  population_total  \
# 0          Abohar            3          PUNJAB          9            145238
# 1        Achalpur           27     MAHARASHTRA          7            112293
# 2        Adilabad           28  ANDHRA PRADESH          1            117388
# 3       Adityapur           20       JHARKHAND         24            173988
# 4           Adoni           28  ANDHRA PRADESH         21            166537
# ..             ...         ...             ...        ...               ...
# 488  Vizianagaram           28  ANDHRA PRADESH         12            227533
# 489      Warangal           28  ANDHRA PRADESH          9            620116
# 490        Wardha           27     MAHARASHTRA          8            105543
# 491   Yamunanagar            6         HARYANA          3            216628
# 492      Yavatmal           27     MAHARASHTRA         14            116714
#
# ...

# %%
data=data[['state_name','sex_ratio']][data['sex_ratio']==data['sex_ratio'].max()]
data
# Out:
#     state_name  sex_ratio
# 278     KERALA       1093

# %%
import pandas as pd
aa=pd.read_table("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv")
aa
bb=pd.read_txt("https://github.com/justmarkham/DAT8/blob/master/data/beer.txt")
bb
cc=pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv")
cc
dd=pd.read_html("https://github.com/vincentarelbundock/Rdatasets/blob/master/datasets.csv")
dd
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
import pandas as pd
items=pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep='\t',chunksize=300,skiprows=[0,2,3,4],nrows=3,na_values=['2','1.0'])
#to change the column as index
aaa=items.copy
aaa=pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep='\t',index_col=['order_id','quantity'])
aaa
items
#300 bytes ly it read by using chunksize,we can give any number instead of 300
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-200-323a7e49d72d> in <module>
#       2 items=pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep='\t',chunksize=300,skiprows=[0,2,3,4],nrows=3,na_values=['2','1.0'])
#       3 #to change the column as index
# ----> 4 aaa=items.copy
#       5 aaa=pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep='\t',index_col=['order_id','quantity'])
#       6 aaa
#
# AttributeError: 'TextFileReader' object has no attribute 'copy'

# %%
#to save the manipulated data ie)analysed data
items=pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep='\t',names=[1,2,3,4,5])
items.to_csv("data_eg.csv",sep="@",index=False,header=False,columns=[1,2,3,4,5])
items.shape
#to convert /store our data in binary format
items.to_pickle("testpick")#this file will available in home but not able to open for that have to use pwd() to know the path working directory and then find the file name called testpick its in a binary form

# %%
pwd()
# Out:
# 'C:\\Users\\sowndariya'

# %%
pd.read_pickle("testpick")#serialisation and deserialisation(serde)object to byte and byte to object
# Out:
#              1         2                                      3  \
# 0     order_id  quantity                              item_name
# 1            1         1           Chips and Fresh Tomato Salsa
# 2            1         1                                   Izze
# 3            1         1                       Nantucket Nectar
# 4            1         1  Chips and Tomatillo-Green Chili Salsa
# ...        ...       ...                                    ...
# 4618      1833         1                          Steak Burrito
# 4619      1833         1                          Steak Burrito
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
# 4622      1834         1                     Chicken Salad Bowl
#
#                                                       4           5
# 0                                    choice_description  item_price
# ...

# %%
cc=pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv",sep=",")
cc
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
bb=pd.read_csv("https://github.com/justmarkham/DAT8/blob/master/data/beer.txt")
bb
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-169-c75f0ab7a606> in <module>
# ----> 1 bb=pd.read_txt("https://github.com/justmarkham/DAT8/blob/master/data/beer.txt")
#       2 bb
#
# D:\Programdata\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     260             return _SparseArray
#     261
# --> 262         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     263
#     264
#
# AttributeError: module 'pandas' has no attribute 'read_txt'

# %%
import pandas as pd
html=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2016.html")
len(html)
html[1]
html[2]
html[3]
html[0]
# Out:
#       Eastern Conference   W   L   W/L%    GB   PS/G   PA/G   SRS
# 0   Cleveland Cavaliers*  57  25  0.695     —  104.3   98.3  5.45
# 1       Toronto Raptors*  56  26  0.683   1.0  102.7   98.2  4.08
# 2            Miami Heat*  48  34  0.585   9.0  100.0   98.4  1.50
# 3         Atlanta Hawks*  48  34  0.585   9.0  102.8   99.2  3.49
# 4        Boston Celtics*  48  34  0.585   9.0  105.7  102.5  2.84
# 5     Charlotte Hornets*  48  34  0.585   9.0  103.4  100.7  2.36
# 6        Indiana Pacers*  45  37  0.549  12.0  102.2  100.5  1.62
# 7       Detroit Pistons*  44  38  0.537  13.0  102.0  101.4  0.43
# 8          Chicago Bulls  42  40  0.512  15.0  101.6  103.1 -1.46
# 9     Washington Wizards  41  41  0.500  16.0  104.1  104.6 -0.50
# 10         Orlando Magic  35  47  0.427  22.0  102.1  103.7 -1.68
# 11       Milwaukee Bucks  33  49  0.402  24.0   99.0  103.2 -3.98
# 12       New York Knicks  32  50  0.390  25.0   98.4  101.1 -2.74
# ...

# %%
excelfile=pd.read_excel("gapminder.xlsx",sheet_name=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8ae294b93071> in <module>
# ----> 1 excelfile=pd.read_excel("gapminder.xlsx",sheet_name=0)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np
print(pd.date_range('22-09-2019',periods=7,freq='Y'))
print(pd.date_range('22-09-2019',periods=7,freq='D'))
date=pd.date_range('22-09-2019',periods=7,freq='M')
s=pd.Series(date,index=[0,1,2,3,4,5,6])
print(s)
s[3]
# Out:
# DatetimeIndex(['2019-12-31', '2020-12-31', '2021-12-31', '2022-12-31',
#                '2023-12-31', '2024-12-31', '2025-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')
# DatetimeIndex(['2019-09-22', '2019-09-23', '2019-09-24', '2019-09-25',
#                '2019-09-26', '2019-09-27', '2019-09-28'],
#               dtype='datetime64[ns]', freq='D')
# 0   2019-09-30
# 1   2019-10-31
# 2   2019-11-30
# 3   2019-12-31
# 4   2020-01-31
# 5   2020-02-29
# 6   2020-03-31
# dtype: datetime64[ns]
# Timestamp('2019-12-31 00:00:00')

# %%
abc=['a','b','c']
num1=[1,2,3]
num2=[1,2,3]
lis=list(zip(num1,num2))
k,v=abc,lis
print(k)
print(v)
list(zip(k,zip(num1,num2)))
{k:v for k,v in zip(k,zip(num1,num2))}
# Out:
# ['a', 'b', 'c']
# [(1, 1), (2, 2), (3, 3)]
# {'a': (1, 1), 'b': (2, 2), 'c': (3, 3)}

# %%
obj='''
{
  "users": [
    {
      "userId": 1,
      "firstName": "Krish",
      "lastName": "Lee",
      "phoneNumber": "123456",
      "emailAddress": "krish.lee@learningcontainer.com"
    },
    {
      "userId": 2,
      "firstName": "racks",
      "lastName": "jacson",
      "phoneNumber": "123456",
      "emailAddress": "racks.jacson@learningcontainer.com"
    },
    {
      "userId": 3,
      "firstName": "denial",
      "lastName": "roast",
      "phoneNumber": "33333333",
      "emailAddress": "denial.roast@learningcontainer.com"
    },
    {
      "userId": 4,
      "firstName": "devid",
      "lastName": "neo",
      "phoneNumber": "222222222",
      "emailAddress": "devid.neo@learningcontainer.com"
    },
    {
      "userId": 5,
      "firstName": "jone",
      "lastName": "mac",
      "phoneNumber": "111111111",
      "emailAddress": "jone.mac@learningcontainer.com"
    }
  ]
}
'''
type(obj)
# Out:
# str

# %%
import json
j=json.loads(obj)
dfff=pd.DataFrame(j['users'])
dfff.to_json('json_eg',orient='records')#to remove index in stored json file we using orient

# %%
import requests
url="https://api.github.com/repos/pandas-dev/pandas/issues"
r=requests.get(url)
r.json()
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/35733',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/35733/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/35733/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/35733/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/35733',
#   'id': 679437691,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0NDY4MjEyNTEz',
#   'number': 35733,
#   'title': 'BLD: update min versions #35732',
#   'user': {'login': 'VirosaLi',
#    'id': 7614606,
#    'node_id': 'MDQ6VXNlcjc2MTQ2MDY=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/7614606?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/VirosaLi',
#    'html_url': 'https://github.com/VirosaLi',
#    'followers_url': 'https://api.github.com/users/VirosaLi/followers',
# ...

# %%
u=r.json()
pd.DataFrame(u,columns=['state','url','number'])#to view selected columns ly
# Out:
#    state                                                url  number
# 0   open  https://api.github.com/repos/pandas-dev/pandas...   35733
# 1   open  https://api.github.com/repos/pandas-dev/pandas...   35732
# 2   open  https://api.github.com/repos/pandas-dev/pandas...   35731
# 3   open  https://api.github.com/repos/pandas-dev/pandas...   35730
# 4   open  https://api.github.com/repos/pandas-dev/pandas...   35727
# 5   open  https://api.github.com/repos/pandas-dev/pandas...   35725
# 6   open  https://api.github.com/repos/pandas-dev/pandas...   35724
# 7   open  https://api.github.com/repos/pandas-dev/pandas...   35719
# 8   open  https://api.github.com/repos/pandas-dev/pandas...   35715
# 9   open  https://api.github.com/repos/pandas-dev/pandas...   35713
# 10  open  https://api.github.com/repos/pandas-dev/pandas...   35712
# 11  open  https://api.github.com/repos/pandas-dev/pandas...   35711
# 12  open  https://api.github.com/repos/pandas-dev/pandas...   35706
# ...

# %%
html1=pd.read_html("https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/banklist.html")
len(html1)
html1[0].dtypes
# Out:
# Bank Name                object
# City                     object
# ST                       object
# CERT                      int64
# Acquiring Institution    object
# Closing Date             object
# dtype: object

# %%
ee=pd.to_datetime(html1[0]['Closing Date'])
html1[0]['Closing Date']=ee
html1[0]
# Out:
#                              Bank Name           City  ST   CERT  \
# 0                 The First State Bank  Barboursville  WV  14361
# 1                   Ericson State Bank        Ericson  NE  18265
# 2     City National Bank of New Jersey         Newark  NJ  21111
# 3                        Resolute Bank         Maumee  OH  58317
# 4                Louisa Community Bank         Louisa  KY  58112
# ..                                 ...            ...  ..    ...
# 556                 Superior Bank, FSB       Hinsdale  IL  32646
# 557                Malta National Bank          Malta  OH   6629
# 558    First Alliance Bank & Trust Co.     Manchester  NH  34264
# 559  National State Bank of Metropolis     Metropolis  IL   3815
# 560                   Bank of Honolulu       Honolulu  HI  21029
#
#                    Acquiring Institution Closing Date   datetime
# 0                         MVB Bank, Inc.   2020-04-03 2020-04-03
# ...

# %%
day=ee.dt.weekofyear#press tab to select year,weekofyear,month etc...
day
# Out:
# 0      14
# 1       7
# 2      44
# 3      43
# 4      43
#        ..
# 556    30
# 557    18
# 558     5
# 559    50
# 560    41
# Name: Closing Date, Length: 561, dtype: int64

# %%
ee.dt.year.value_counts()
# Out:
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
# 2013     24
# 2014     18
# 2002     11
# 2017      8
# 2015      8
# 2016      5
# 2001      4
# 2019      4
# 2004      4
# 2007      3
# 2003      3
# 2020      2
# 2000      2
# Name: Closing Date, dtype: int64

# %%
train=pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/fa71405126017e6a37bea592440b4bee94bf7b9e/titanic.csv")
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.columns
train.shape
train.head()
list(train.index)
type(train.Name)
train[['Name','Pclass','Fare']]
train.describe()
i=train.dtypes[train.dtypes=='object'].index#to get object dtypes as dataframe
train[i]
train[i].describe()
# Out:
#                                Name   Sex Ticket    Cabin Embarked
# count                           891   891    891      204      889
# unique                          891     2    681      147        3
# top     Hansen, Mr. Henry Damsgaard  male   1601  B96 B98        S
# freq                              1   577      7        4      644

# %%
del html1[0]['datetime']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Programdata\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'datetime'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-121-7953ba05d7bb> in <module>
# ----> 1 del html1[0]['datetime']
#
# ...

# %%
del html1[0]['month']

# %%
del train['Pclass']

# %%
train['sum']=train['SibSp']+train['Parch']
train
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %%
from numpy.random import randn as rn
np.random.seed(1000)#to get same random data
r=rn(4,5)
pdd=pd.DataFrame(r,columns=['1st row','2nd row','3rd row','4th row','5th row'],index=['a','b','c','d'])
pdd
# Out:
#     1st row   2nd row   3rd row   4th row   5th row
# a -0.804458  0.320932 -0.025483  0.644324 -0.300797
# b  0.389475 -0.107437 -0.479983  0.595036 -0.464668
# c  0.667281 -0.806116 -1.196070 -0.405960 -0.182377
# d  0.103193 -0.138422  0.705692  1.271795 -0.986747

# %%
pdd[['1st row','2nd row']]
# Out:
#     1st row   2nd row
# a -0.804458  0.320932
# b  0.389475 -0.107437
# c  0.667281 -0.806116
# d  0.103193 -0.138422

# %%
pdd['sum']=pdd['1st row']+pdd['2nd row']
pdd
# Out:
#     1st row   2nd row   3rd row   4th row   5th row       sum
# a -0.804458  0.320932 -0.025483  0.644324 -0.300797 -0.483527
# b  0.389475 -0.107437 -0.479983  0.595036 -0.464668  0.282037
# c  0.667281 -0.806116 -1.196070 -0.405960 -0.182377 -0.138834
# d  0.103193 -0.138422  0.705692  1.271795 -0.986747 -0.035229

# %%
pdd.drop('a')#by default axis=0
pdd.drop('1st row',axis=1)
pdd#to drop rows and columns permanently from the table or use reassign
pdd=pdd.drop('c')
pdd.drop('a',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-158-7ebf15622079> in <module>
# ----> 1 pdd.drop('a')#by default axis=0
#       2 pdd.drop('1st row',axis=1)
#       3 pdd#to drop rows and columns permanently from the table or use reassign
#       4 #pdd=pdd.drop('c')
#       5 #pdd.drop('a',inplace=True)
#
# D:\Programdata\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# D:\Programdata\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# ...

# %%
pdd=pdd.drop('b')
pdd
# Out:
#     1st row   2nd row   3rd row   4th row   5th row       sum
# c  0.667281 -0.806116 -1.196070 -0.405960 -0.182377 -0.138834
# d  0.103193 -0.138422  0.705692  1.271795 -0.986747 -0.035229

# %%
print(pdd.iloc[0:1,2:3])
pdd.loc[['c'],['3rd row']]
pdd.loc[['c','d'],['2nd row','sum']]#diff between iloc and loc 
pdd.iloc[[0,1],[2,3]]
pdd.iloc[::2,:]
pdd.iloc[::-1,::-1]
pdd.iloc[[0,1]]
# Out:
#    3rd row
# c -1.19607
#     1st row   2nd row   3rd row   4th row   5th row       sum
# c  0.667281 -0.806116 -1.196070 -0.405960 -0.182377 -0.138834
# d  0.103193 -0.138422  0.705692  1.271795 -0.986747 -0.035229

# %%
pdd.loc[['c','d']]#works data with named indexes
train.iloc[['1','2']]#works with integer index which is default index
# Out:
#    PassengerId  Survived                                               Name  \
# 1            2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3         1                             Heikkinen, Miss. Laina
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  sum
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C    1
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S    0

# %%
import pandas as pd
import numpy as np
from numpy.random import randn as rn
np.random.seed(10010)#to get same random data
r=rn(4,5)
p=pd.DataFrame(r,columns=['1st row','2nd row','3rd row','4th row','5th row'],index=['a','b','c','d'])
p[p>1]
print(p[p.loc[['a','b','c']]>1])
[p['1st row']>-1]
print([p.loc[['b']]>1])
p[(p['1st row']>0)|(p['2nd row']>0)]['5th row']#the condition applied to the particular column
# Out:
#    1st row  2nd row  3rd row  4th row  5th row
# a      NaN      NaN      NaN      NaN      NaN
# b      NaN      NaN      NaN      NaN      NaN
# c      NaN      NaN      NaN      NaN      NaN
# d      NaN      NaN      NaN      NaN      NaN
# [   1st row  2nd row  3rd row  4th row  5th row
# b    False    False    False    False    False]
# a    0.173561
# Name: 5th row, dtype: float64

# %%
p.reset_index()
# Out:
#   index   1st row   2nd row   3rd row   4th row   5th row
# 0     a  0.634524 -1.153273  0.218871  0.253713  0.173561
# 1     b -0.681482 -1.937160  0.209099  0.558817  0.029207
# 2     c -1.378289 -0.798493 -1.234701  0.441544  0.413130
# 3     d -0.265578 -0.346660  1.524922 -0.744971  0.794184

# %%
p.reset_index(drop=True)
# Out:
#     1st row   2nd row   3rd row   4th row   5th row
# 0  0.634524 -1.153273  0.218871  0.253713  0.173561
# 1 -0.681482 -1.937160  0.209099  0.558817  0.029207
# 2 -1.378289 -0.798493 -1.234701  0.441544  0.413130
# 3 -0.265578 -0.346660  1.524922 -0.744971  0.794184

# %%
p#we get the same data again for that keep inplace =true to did the changes or reassign p=p.reset_index(drop=True)
# Out:
#     1st row   2nd row   3rd row   4th row   5th row
# a  0.634524 -1.153273  0.218871  0.253713  0.173561
# b -0.681482 -1.937160  0.209099  0.558817  0.029207
# c -1.378289 -0.798493 -1.234701  0.441544  0.413130
# d -0.265578 -0.346660  1.524922 -0.744971  0.794184

# %%
p.reset_index(drop=True,inplace=True)
p
# Out:
#     1st row   2nd row   3rd row   4th row   5th row
# 0  0.634524 -1.153273  0.218871  0.253713  0.173561
# 1 -0.681482 -1.937160  0.209099  0.558817  0.029207
# 2 -1.378289 -0.798493 -1.234701  0.441544  0.413130
# 3 -0.265578 -0.346660  1.524922 -0.744971  0.794184

# %%
p.set_index('5th row',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-f4e455c7bbf7> in <module>
# ----> 1 p.set_index('5th row',inplace=True)
#       2 p.index()
#
# D:\Programdata\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['5th row'] are in the columns"

# %%
p.index
p
# Out:
#     1st row   2nd row   3rd row   4th row   5th row
# a  0.634524 -1.153273  0.218871  0.253713  0.173561
# b -0.681482 -1.937160  0.209099  0.558817  0.029207
# c -1.378289 -0.798493 -1.234701  0.441544  0.413130
# d -0.265578 -0.346660  1.524922 -0.744971  0.794184

# %%
p.loc[0.029207]#showa error if we using the index of numpy random actually it shows ly 6 digits
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Programdata\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Float64HashTable.get_item()
#
# KeyError: 0.029207
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-e2c2beb152dc> in <module>
# ...

# %%
p.index#by this we can get all the index values i took 0.17356101210307498
p.loc[0.17356101210307498]#for accessing row have to mention loc
# Out:
# 1st row    0.634524
# 2nd row   -1.153273
# 3rd row    0.218871
# 4th row    0.253713
# Name: 0.17356101210307498, dtype: float64

# %%
add_new_col='hi this is riya'
p['str']=add_new_col.split()
p.set_index('str',inplace=True)
p
# Out:
#        1st row   2nd row   3rd row   4th row
# str
# hi    0.634524 -1.153273  0.218871  0.253713
# this -0.681482 -1.937160  0.209099  0.558817
# is   -1.378289 -0.798493 -1.234701  0.441544
# riya -0.265578 -0.346660  1.524922 -0.744971

# %%
p.loc['riya']
# Out:
# 1st row   -0.265578
# 2nd row   -0.346660
# 3rd row    1.524922
# 4th row   -0.744971
# Name: riya, dtype: float64

# %%
pdict=pd.DataFrame({'A':['a','riya',100],'B':['b','ram',10],'C':['c','sara',20]},index=[0,1,2],columns=['Grade','Names','Marks'])
pdict
# Out:
#   Grade Names Marks
# 0   NaN   NaN   NaN
# 1   NaN   NaN   NaN
# 2   NaN   NaN   NaN

# %%
pdict=pd.DataFrame({'A':['a','riya',100,np.NaN],'B':['b','ram',111,np.NaN],'C':['c','sara',10,np.NaN],'D':[np.NaN,np.NaN,np.NaN,np.NaN]})
print(pdict)
pdict.dropna(axis=1)#to drop column with NaN 
#pdict.fillna(1)
# Out:
#       A    B     C   D
# 0     a    b     c NaN
# 1  riya  ram  sara NaN
# 2   100  111    10 NaN
# 3   NaN  NaN   NaN NaN
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
pdict.dropna(axis=1,thresh=3,inplace=True)#to drop row with NaN thresh-remove the column completely with NaN ly..if axis=0 and thresh=1 then it removes the row completely with NaN ly
#thresh calculate the no of not NaN values
pdict.dropna(axis=0,thresh=3)#the below two rows having 3 not NaN values hence it came
# Out:
#       A    B     C
# 0     a    b     c
# 1  riya  ram  sara
# 2   100  111    10

# %%
pdict.pivot('A','B')
# Out:
#         C                   D
# B     NaN  111    b   ram NaN 111   b ram
# A
# NaN   NaN  NaN  NaN   NaN NaN NaN NaN NaN
# 100   NaN   10  NaN   NaN NaN NaN NaN NaN
# a     NaN  NaN    c   NaN NaN NaN NaN NaN
# riya  NaN  NaN  NaN  sara NaN NaN NaN NaN

# %%
pdict.groupby('A').describe()
# Out:
#          B                      C
#      count unique  top freq count unique   top freq
# A
# 100      1      1  111    1     1      1    10    1
# a        1      1    b    1     1      1     c    1
# riya     1      1  ram    1     1      1  sara    1

# %%
pdict.dropna(thresh=2)
# Out:
#       A    B     C   D
# 0     a    b     c NaN
# 1  riya  ram  sara NaN
# 2   100  111    10 NaN

# %%
dff=pd.DataFrame(train.groupby(['Sex']).describe())
dff['PassengerId']['mean']
# Out:
# Sex
# female    431.028662
# male      454.147314
# Name: mean, dtype: float64

# %%
dff=pd.DataFrame(train.groupby(['Sex']).describe().iloc[1])

dff.loc['PassengerId'].loc['min']
#dff.loc['PassengerId'].loc['mean']
dff.T
# Out:
#      PassengerId                                                           \
#            count        mean         std  min    25%    50%    75%    max
# male       577.0  454.147314  257.486139  1.0  222.0  464.0  680.0  891.0
#
#      Survived            ... Parch        Fare                             \
#         count      mean  ...   75%  max  count       mean        std  min
# male    577.0  0.188908  ...   0.0  5.0  577.0  25.523893  43.138263  0.0
#
#
#          25%   50%    75%       max
# male  7.8958  10.5  26.55  512.3292
#
# [1 rows x 56 columns]

# %%
pd.DataFrame(train.groupby(['Sex']).describe().iloc[0]).T
# Out:
#        PassengerId                                                             \
#              count        mean         std  min     25%    50%     75%    max
# female       314.0  431.028662  256.846324  2.0  231.75  414.5  641.25  889.0
#
#        Survived            ... Parch        Fare                              \
#           count      mean  ...   75%  max  count       mean        std   min
# female    314.0  0.742038  ...   1.0  6.0  314.0  44.479818  57.997698  6.75
#
#
#               25%   50%   75%       max
# female  12.071875  23.0  55.0  512.3292
#
# [1 rows x 56 columns]

# %%
aaa=train.describe()
a=aaa.loc[['count'],'Age']
train
a
# Out:
# count    714.0
# Name: Age, dtype: float64

# %%
aaa.index
train.loc[[3,4]]['Age']
pd.merge(df1,df2,how='right',left_on='colname',right_on='colname')#like join operation in sql choose left ,right,full,outer #depends on which column perform join present on both table
df1.join(df2)#df1 is left table and df2 is right table
# Out:
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64
